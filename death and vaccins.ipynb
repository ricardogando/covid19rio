# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
death = pd.read_csv('owid-covid-dataEUA.csv')

# %%
vaccin = pd.read_csv('daily-covid-vaccination-doses-per-capitaUSA.csv')

# %%
death.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
vaccin.columns
# Out:
# Index(['Entity', 'Code', 'Day', 'new_vaccinations_smoothed_per_million'], dtype='object')

# %%
usadeath = death[death.iso_code == 'USA']

# %%
vaccin
# Out:
#             Entity Code         Day  new_vaccinations_smoothed_per_million
# 0      Afghanistan  AFG  2021-02-23                                 0.0034
# 1      Afghanistan  AFG  2021-02-24                                 0.0034
# 2      Afghanistan  AFG  2021-02-25                                 0.0034
# 3      Afghanistan  AFG  2021-02-26                                 0.0034
# 4      Afghanistan  AFG  2021-02-27                                 0.0034
# ...            ...  ...         ...                                    ...
# 50389     Zimbabwe  ZWE  2021-09-23                                 0.1914
# 50390     Zimbabwe  ZWE  2021-09-24                                 0.2073
# 50391     Zimbabwe  ZWE  2021-09-25                                 0.2141
# 50392     Zimbabwe  ZWE  2021-09-26                                 0.2081
# 50393     Zimbabwe  ZWE  2021-09-27                                 0.2073
#
# [50394 rows x 4 columns]

# %%
usavaccin = vaccin[vaccin.Code == 'USA']
bravaccin = vaccin[vaccin.Code == 'BRA']

# %%
bradeath = death[death.iso_code == 'BRA']

# %%
deltabra = '2021-06-28'
deltausa = '2021-'

# %%
fig, ax = plt.subplots()

ax.plot(usadeath.date, usadeath.new_deaths_smoothed/3000, label='EUA Morte')
ax.plot(bradeath.date, bradeath.new_deaths_smoothed/3000, label='BRA')
ax.plot(usavaccin.Day, usavaccin.new_vaccinations_smoothed_per_million, '--', label='EUA Vac')
ax.plot(bravaccin.Day, bravaccin.new_vaccinations_smoothed_per_million, '--', label='BRA')
ax.legend()
plt.xlabel('Dias')
plt.ylabel('Arbitraria')

# Major ticks every 6 months.
fmt_half_year = mdates.MonthLocator(interval=6)
ax.xaxis.set_major_locator(fmt_half_year)

# Minor ticks every month.
fmt_month = mdates.MonthLocator()
ax.xaxis.set_minor_locator(fmt_month)

# Text in the x axis will be displayed in 'YYYY-mm' format.
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

#plt.tight_layout()
plt.savefig('mortes_e_vacinas.png', dpi=300)

# %%
fig, ax = plt.subplots()

ax.plot(usadeath.date, usadeath.new_deaths_smoothed, label='EUA Morte')
ax.plot(bradeath.date, bradeath.new_deaths_smoothed, label='BRA')
#ax.plot(usavaccin.Day, usavaccin.new_vaccinations_smoothed_per_million, '--', label='EUA Vac')
#ax.plot(bravaccin.Day, bravaccin.new_vaccinations_smoothed_per_million, '--', label='BRA')
ax.legend()
plt.xlabel('Dias')
plt.ylabel('novas mortes (suave)')

# Major ticks every 6 months.
fmt_half_year = mdates.MonthLocator(interval=6)
ax.xaxis.set_major_locator(fmt_half_year)

# Minor ticks every month.
fmt_month = mdates.MonthLocator()
ax.xaxis.set_minor_locator(fmt_month)

# Text in the x axis will be displayed in 'YYYY-mm' format.
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

#plt.tight_layout()
plt.savefig('mortes.png', dpi=300)

# %%
fig, ax = plt.subplots()

#ax.plot(usadeath.date, usadeath.new_deaths_smoothed, label='EUA Morte')
#ax.plot(bradeath.date, bradeath.new_deaths_smoothed, label='BRA')
ax.plot(usavaccin.Day, usavaccin.new_vaccinations_smoothed_per_million, '--', label='EUA Vac')
ax.plot(bravaccin.Day, bravaccin.new_vaccinations_smoothed_per_million, '--', label='BRA')
ax.legend()
plt.xlabel('Dias')
plt.ylabel('novas vacinas (suave) por milhao')

# Major ticks every 6 months.
fmt_half_year = mdates.MonthLocator(interval=6)
ax.xaxis.set_major_locator(fmt_half_year)

# Minor ticks every month.
fmt_month = mdates.MonthLocator()
ax.xaxis.set_minor_locator(fmt_month)

# Text in the x axis will be displayed in 'YYYY-mm' format.
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

#plt.tight_layout()
plt.savefig('vacinas.png', dpi=300)
